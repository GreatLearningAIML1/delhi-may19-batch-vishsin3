# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %% [markdown]
# ### Import the necessary libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import csv
import numpy as np
from PIL import Image

from keras import Model
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.layers import Conv2D, Reshape
from keras.utils import Sequence
from keras.backend import epsilon
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
# !pip install patool
# Out:
# Collecting patool
#   Downloading https://files.pythonhosted.org/packages/43/94/52243ddff508780dd2d8110964320ab4851134a55ab102285b46e740f76a/patool-1.12-py2.py3-none-any.whl (77kB)
#      |████████████████████████████████| 81kB 3.4MB/s
# Installing collected packages: patool
# Successfully installed patool-1.12

# %%
import patoolib
patoolib.extract_archive('/content/drive/My Drive/Data  Science/images_racoon.rar')
# Out:
# patool: Extracting /content/drive/My Drive/Data  Science/images_racoon.rar ...
# patool: running /usr/bin/unrar x -- "/content/drive/My Drive/Data  Science/images_racoon.rar"
# patool:     with cwd='./Unpack_pvaaxs37'
# patool: ... /content/drive/My Drive/Data  Science/images_racoon.rar extracted to `images_racoon' (local file exists).
# 'images_racoon'

# %% [markdown]
# ### Change directory

# %%
import os
os.chdir('/content/drive/My Drive/Data  Science/')

# %% [markdown]
# ### Load the training data from train.csv file

# %%
ALPHA = 1.0 # Width hyper parameter for MobileNet (0.25, 0.5, 0.75, 1.0). Higher width means more accurate but slower

EPOCHS = 10 # Number of epochs. I got decent performance with just 5.
BATCH_SIZE = 32 # Depends on your GPU or CPU RAM.

DATASET_FOLDER = "/content/drive/My Drive/Data  Science/"
TRAIN_CSV = DATASET_FOLDER+'train_labels.csv'

images_zip_path = DATASET_FOLDER + "images_racoon"

# %% [markdown]
# ### Print the shape of the train dataset

# %%
train = pd.read_csv('train_labels.csv')
train.shape
# Out:
# (173, 8)

# %%
TRAIN_CSV
# Out:
# '/content/drive/My Drive/Data  Science/train_labels.csv'

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
IMAGE_SIZE = 128 # MobileNet takes images of size 128*128*3

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
import csv
with open(TRAIN_CSV, 'r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile)-1, 4))
    reader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    next(csvfile)
    for col, row in enumerate(reader):
               
        #for i, r in enumerate(row[1:8]): # Parse row with seven entities
            #row[i+1] = int(r)
        path, image_height, image_width, x0, y0, x1, y1 = row[0],int(row[2]),int(row[1]),int(row[4]),int(row[5]),int(row[6]),int(row[7])
        #path = "./" + path.split('/')[-2] + "/" + path.split('/')[-1]
        path= DATASET_FOLDER + 'images/' +path
        coords[col, 0] = x0 * IMAGE_SIZE / image_width # Normalize bounding box by image size
        coords[col, 1] = y0 * IMAGE_SIZE / image_height # Normalize bounding box by image size
        coords[col, 2] = (x1 - x0) * IMAGE_SIZE / image_width # Normalize bounding box by image size
        coords[col, 3] = (y1 - y0) * IMAGE_SIZE / image_height
        paths.append(path)

batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, f in enumerate(paths):
    img = Image.open(f) # Read image
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE)) # Resize image
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, f in enumerate(paths):
    img = Image.open(f) # Read image
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE)) # Resize image
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
model = MobileNet(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, alpha=ALPHA) # Load pre-trained mobilenet

# to freeze layers, except the new top layer, of course, which will be added below
for layer in model.layers:
    layer.trainable = False

# Add new top layer which is a conv layer of the same size as the previous layer so that only 4 coords of BBox can be output
x = model.layers[-1].output
x = Conv2D(4, kernel_size=4, name="coords")(x)
# In the line above kernel size should be 3 for img size 96, 4 for img size 128, 5 for img size 160 etc.
x = Reshape((4,))(x) # These are the 4 predicted coordinates of one BBox

model = Model(inputs=model.input, outputs=x)

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
gt = coords

# %%
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_func(loss, [y_true, y_pred], tf.float32)
    return iou

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
model.compile(optimizer='Adam', loss='mse', metrics=[IoU]) # Regression loss is MSE

#checkpoint = ModelCheckpoint("model-{val_iou:.2f}.h5", verbose=1, save_best_only=True,
#                              save_weights_only=True, mode="max", period=1) # Checkpoint best validation model
#stop = EarlyStopping(monitor="val_iou", patience=PATIENCE, mode="max") # Stop early, if the validation error deteriorates
#reduce_lr = ReduceLROnPlateau(monitor="val_iou", factor=0.2, patience=10, min_lr=1e-7, verbose=1, mode="max")
# Reduce learning rate if Validation IOU does not improve

model.fit(batch_images,gt,
            epochs=30,batch_size = 32,
            verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/30
# 173/173 [==============================] - 7s 38ms/step - loss: 2918.3790 - IoU: 0.0815
# Epoch 2/30
# 173/173 [==============================] - 5s 29ms/step - loss: 718.7852 - IoU: 0.4216
# Epoch 3/30
# 173/173 [==============================] - 5s 30ms/step - loss: 675.9050 - IoU: 0.5251
# Epoch 4/30
# 173/173 [==============================] - 5s 30ms/step - loss: 589.5598 - IoU: 0.5322
# Epoch 5/30
# 173/173 [==============================] - 5s 30ms/step - loss: 367.8464 - IoU: 0.5862
# Epoch 6/30
# 173/173 [==============================] - 5s 29ms/step - loss: 270.0507 - IoU: 0.5830
# Epoch 7/30
# 173/173 [==============================] - 5s 30ms/step - loss: 257.5439 - IoU: 0.5898
# Epoch 8/30
# 173/173 [==============================] - 5s 30ms/step - loss: 203.6120 - IoU: 0.6503
# Epoch 9/30
# 173/173 [==============================] - 5s 30ms/step - loss: 167.9126 - IoU: 0.6958
# Epoch 10/30
# 173/173 [==============================] - 5s 29ms/step - loss: 142.3802 - IoU: 0.7172
# Epoch 11/30
# 173/173 [==============================] - 5s 30ms/step - loss: 138.5722 - IoU: 0.7179
# Epoch 12/30
# 173/173 [==============================] - 5s 30ms/step - loss: 125.2202 - IoU: 0.7222
# Epoch 13/30
# 173/173 [==============================] - 5s 30ms/step - loss: 113.2968 - IoU: 0.7408
# Epoch 14/30
# 173/173 [==============================] - 5s 30ms/step - loss: 101.4214 - IoU: 0.7564
# Epoch 15/30
# 173/173 [==============================] - 5s 30ms/step - loss: 96.0323 - IoU: 0.7600
# Epoch 16/30
# 173/173 [==============================] - 5s 30ms/step - loss: 98.0387 - IoU: 0.7606
# Epoch 17/30
# 173/173 [==============================] - 5s 30ms/step - loss: 88.4807 - IoU: 0.7673
# Epoch 18/30
# 173/173 [==============================] - 5s 30ms/step - loss: 76.9677 - IoU: 0.7934
# Epoch 19/30
# 173/173 [==============================] - 5s 30ms/step - loss: 74.0194 - IoU: 0.7948
# Epoch 20/30
# 173/173 [==============================] - 5s 30ms/step - loss: 72.6892 - IoU: 0.8051
# Epoch 21/30
# 173/173 [==============================] - 5s 30ms/step - loss: 68.4720 - IoU: 0.8149
# Epoch 22/30
# 173/173 [==============================] - 5s 29ms/step - loss: 66.0027 - IoU: 0.8112
# Epoch 23/30
# 173/173 [==============================] - 5s 30ms/step - loss: 62.4751 - IoU: 0.8222
# Epoch 24/30
# 173/173 [==============================] - 5s 30ms/step - loss: 63.3591 - IoU: 0.8207
# Epoch 25/30
# 173/173 [==============================] - 5s 30ms/step - loss: 66.3536 - IoU: 0.8172
# Epoch 26/30
# 173/173 [==============================] - 5s 30ms/step - loss: 62.5015 - IoU: 0.8285
# Epoch 27/30
# 173/173 [==============================] - 5s 30ms/step - loss: 63.5683 - IoU: 0.8257
# Epoch 28/30
# 173/173 [==============================] - 5s 30ms/step - loss: 67.6625 - IoU: 0.8169
# Epoch 29/30
# 173/173 [==============================] - 5s 30ms/step - loss: 64.1232 - IoU: 0.8221
# Epoch 30/30
# 173/173 [==============================] - 5s 30ms/step - loss: 60.1740 - IoU: 0.8350

# %% [markdown]
# ### Pick a test image from the given data

# %%
import cv2
filename = './images/raccoon-60.jpg'
unscaled = cv2.imread(filename) # Original image for display

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
image_height, image_width, _ = unscaled.shape
image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE)) # Rescaled image to run the network
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = model.predict(x=np.array([feat_scaled]))[0] # Predict the BBox
region
# Out:
# array([21.386738, 19.553095, 75.9553  , 84.055626], dtype=float32)

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * image_width / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * image_height / IMAGE_SIZE)

x1 = int((region[2]) * image_width / IMAGE_SIZE)
y1 = int((region[3]) * image_height / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0) , (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %% [markdown]
# # Time Series Prediction using LSTM

# %% [markdown]
# ### Download Data
# Link: https://datamarket.com/data/set/2324/daily-minimum-temperatures-in-melbourne-australia-1981-1990#!ds=2324&display=line
#
# #### Description
# Daily minimum temperatures in Melbourne, Australia, 1981-1990
#
# Units: Degrees Celcius
#
# #### Steps before loading
# - Rename the column name with temprature values to "Temprature"
# - In the last, there is one extra row in the data, remove it by opening the file and save it again.
# - There are some values in Temprature column which have a "?" before them, they will give error, remove "?" before them and save the file
# - If you don't want to do these steps, just load the data file given by Great Learning.

# %% [markdown]
# #### Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Change your present working directory

# %%
import os
os.chdir('/content/drive/My Drive/Data  Science')

# %% [markdown]
# ### Load your data file

# %%
time_series = pd.read_csv('/content/drive/My Drive/Data  Science/daily-minimum-temperatures-in-me.csv')

# %% [markdown]
# #### Plot data

# %%
time_series.plot

# %% [markdown]
# #### Descibe your dataframe

# %%
time_series.describe()
# Out:
#        Temperature
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %% [markdown]
# #### Check for null values

# %%
time_series.isnull().sum()
# Out:
# Date           0
# Temperature    0
# dtype: int64

# %% [markdown]
# #### Drop null values

# %%
time_series.dropna()
# Out:
#             Date  Temperature
# 0     1981-01-01         20.7
# 1     1981-01-02         17.9
# 2     1981-01-03         18.8
# 3     1981-01-04         14.6
# 4     1981-01-05         15.8
# ...          ...          ...
# 3645  1990-12-27         14.0
# 3646  1990-12-28         13.6
# 3647  1990-12-29         13.5
# 3648  1990-12-30         15.7
# 3649  1990-12-31         13.0
#
# [3650 rows x 2 columns]

# %% [markdown]
# #### Get the representation of the distribution of data in the form of histogram

# %%
time_series.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a728db940>]],
#       dtype=object)

# %% [markdown]
# #### Check the maximum and minimum values

# %%
print('Min', np.min(time_series))
print('Max', np.max(time_series))
# Out:
# Min Date           1981-01-01
# Temperature             0
# dtype: object
# Max Date           1990-12-31
# Temperature          26.3
# dtype: object

# %%
time_series.drop("Date", axis=1, inplace=True)

# %% [markdown]
# ### Normalize the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(time_series)

# %% [markdown]
# #### Check the maximum and minimum values of scaled data

# %%
print('Min', np.min(scaled))
print('Max', np.max(scaled))
# Out:
# Min 0.0
# Max 1.0

# %% [markdown]
# #### Look into some of the scaled values

# %%
scaled
# Out:
# array([[0.78707224],
#        [0.68060837],
#        [0.7148289 ],
#        ...,
#        [0.51330798],
#        [0.59695817],
#        [0.49429658]])

# %% [markdown]
# ### Split data into Training and Testing

# %%
#70% examples will used for training (in the begining)
train_size = int(len(scaled) * 0.70)

#30% will be used for Test
test_size = len(scaled - train_size)

# %% [markdown]
# #### Print train and test size

# %%
#Split the data
train, test = scaled[0:train_size, :], scaled[train_size: len(scaled), :]
print('train: {}\ntest: {}'.format(len(train), len(test)))
# Out:
# train: 2555
# test: 1095

# %% [markdown]
# ## Create the sequential data
# Map the temprature at a particular time t to the temprature at time t+n, where n is any number you define.
#
# For example: to map tempratures of consecutive days, use t+1, i.e. loop_back = 1

# %% [markdown]
# #### Define your function to create dataset

# %%
#window - how long the sequence will be
def create_dataset(dataset, window=1):
    
    dataX, dataY = [], []
    
    for i in range(len(dataset)-window):
        
        a = dataset[i:(i+window), 0]        
        dataX.append(a)
        dataY.append(dataset[i + window, 0])
    
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# #### Use function to get training and test set

# %%
#Create Input and Output
window_size = 1
X_train, y_train = create_dataset(train, window_size)
X_test, y_test = create_dataset(test, window_size)

# %% [markdown]
# #### Transform the prepared train and test input data into the expected structure using numpy.reshape()

# %%
#Make it 3 Dimensional Data - needed for LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (2554, 1, 1)
# (1094, 1, 1)

# %% [markdown]
# ## Define Model

# %% [markdown]
# ### Define sequntial model, add LSTM layer and compile the model

# %%
import tensorflow as tf

# %%
tf.keras.backend.clear_session()
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(32, input_shape=(window_size, 1)))
model.add(tf.keras.layers.Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ### Summarize your model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                4352
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Train on 2554 samples, validate on 1094 samples
# Epoch 1/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 2/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 3/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 4/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 5/200
# 2554/2554 [==============================] - 0s 135us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 6/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 7/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 8/200
# 2554/2554 [==============================] - 0s 137us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 9/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 10/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 11/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 12/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 13/200
# 2554/2554 [==============================] - 0s 139us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 14/200
# 2554/2554 [==============================] - 0s 139us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 15/200
# 2554/2554 [==============================] - 0s 139us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 16/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 17/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 18/200
# 2554/2554 [==============================] - 0s 139us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 19/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 20/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 21/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 22/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 23/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 24/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 25/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 26/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 27/200
# 2554/2554 [==============================] - 0s 120us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 28/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 29/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 30/200
# 2554/2554 [==============================] - 0s 123us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 31/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0091
# Epoch 32/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 33/200
# 2554/2554 [==============================] - 0s 117us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 34/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 35/200
# 2554/2554 [==============================] - 0s 143us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 36/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 37/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 38/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 39/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 40/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 41/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 42/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 43/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 44/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 45/200
# 2554/2554 [==============================] - 0s 122us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 46/200
# 2554/2554 [==============================] - 0s 122us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 47/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 48/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 49/200
# 2554/2554 [==============================] - 0s 119us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 50/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 51/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 52/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 53/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 54/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 55/200
# 2554/2554 [==============================] - 0s 117us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 56/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 57/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 58/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 59/200
# 2554/2554 [==============================] - 0s 121us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 60/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 61/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 62/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 63/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 64/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 65/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 66/200
# 2554/2554 [==============================] - 0s 119us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 67/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 68/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 69/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 70/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 71/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 72/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 73/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 74/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0092
# Epoch 75/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 76/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 77/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 78/200
# 2554/2554 [==============================] - 0s 118us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 79/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 80/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 81/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 82/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 83/200
# 2554/2554 [==============================] - 0s 118us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 84/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 85/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 86/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 87/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 88/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 89/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 90/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 91/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 92/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 93/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 94/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 95/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 96/200
# 2554/2554 [==============================] - 0s 116us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 97/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 98/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 99/200
# 2554/2554 [==============================] - 0s 121us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 100/200
# 2554/2554 [==============================] - 0s 114us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 101/200
# 2554/2554 [==============================] - 0s 117us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 102/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 103/200
# 2554/2554 [==============================] - 0s 115us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 104/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 105/200
# 2554/2554 [==============================] - 0s 118us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 106/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 107/200
# 2554/2554 [==============================] - 0s 116us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 108/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 109/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 110/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 111/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 112/200
# 2554/2554 [==============================] - 0s 143us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 113/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 114/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 115/200
# 2554/2554 [==============================] - 0s 107us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 116/200
# 2554/2554 [==============================] - 0s 113us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 117/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 118/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 119/200
# 2554/2554 [==============================] - 0s 120us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 120/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 121/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0099 - val_loss: 0.0087
# Epoch 122/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 123/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 124/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 125/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0101 - val_loss: 0.0088
# Epoch 126/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 127/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0100 - val_loss: 0.0091
# Epoch 128/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 129/200
# 2554/2554 [==============================] - 0s 138us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 130/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 131/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 132/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 133/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 134/200
# 2554/2554 [==============================] - 0s 139us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 135/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 136/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 137/200
# 2554/2554 [==============================] - 0s 143us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 138/200
# 2554/2554 [==============================] - 0s 142us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 139/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 140/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 141/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 142/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 143/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 144/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 145/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 146/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 147/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 148/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 149/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 150/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 151/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 152/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 153/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 154/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 155/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 156/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0099 - val_loss: 0.0088
# Epoch 157/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 158/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 159/200
# 2554/2554 [==============================] - 0s 135us/sample - loss: 0.0099 - val_loss: 0.0091
# Epoch 160/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 161/200
# 2554/2554 [==============================] - 0s 140us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 162/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 163/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 164/200
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 165/200
# 2554/2554 [==============================] - 0s 119us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 166/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0099 - val_loss: 0.0087
# Epoch 167/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 168/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 169/200
# 2554/2554 [==============================] - 0s 125us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 170/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 171/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 172/200
# 2554/2554 [==============================] - 0s 124us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 173/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 174/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 175/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 176/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0099 - val_loss: 0.0087
# Epoch 177/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 178/200
# 2554/2554 [==============================] - 0s 122us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 179/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 180/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 181/200
# 2554/2554 [==============================] - 0s 134us/sample - loss: 0.0099 - val_loss: 0.0087
# Epoch 182/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 183/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 184/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 185/200
# 2554/2554 [==============================] - 0s 132us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 186/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 187/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 188/200
# 2554/2554 [==============================] - 0s 140us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 189/200
# 2554/2554 [==============================] - 0s 128us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 190/200
# 2554/2554 [==============================] - 0s 117us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 191/200
# 2554/2554 [==============================] - 0s 117us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 192/200
# 2554/2554 [==============================] - 0s 137us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 193/200
# 2554/2554 [==============================] - 0s 117us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 194/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 195/200
# 2554/2554 [==============================] - 0s 129us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 196/200
# 2554/2554 [==============================] - 0s 126us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 197/200
# 2554/2554 [==============================] - 0s 130us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 198/200
# 2554/2554 [==============================] - 0s 131us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 199/200
# 2554/2554 [==============================] - 0s 127us/sample - loss: 0.0100 - val_loss: 0.0091
# Epoch 200/200
# 2554/2554 [==============================] - 0s 133us/sample - loss: 0.0100 - val_loss: 0.0087

# %% [markdown]
# ## Make Predictions and Evaluate your model

# %%
#Un-normalize the predited data
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)
trainPredict = scaler.inverse_transform(trainPredict)
testPredict = scaler.inverse_transform(testPredict)

# %% [markdown]
# ## Plot the results

# %%
import matplotlib.pyplot as plt

# %%
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[window_size:len(trainPredict)+window_size, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(window_size*2):len(scaled), :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(scaled))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(scaler.inverse_transform(scaled))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
