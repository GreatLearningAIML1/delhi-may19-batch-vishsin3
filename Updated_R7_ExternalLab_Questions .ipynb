# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf
tf.set_random_seed(42)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
(trainX, trainY),(testX, testY) = tf.keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %%
trainY.shape[0]
# Out:
# 60000

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#Initialize model, reshape & normalize data
tf.keras.backend.clear_session()
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))
model.add(tf.keras.layers.BatchNormalization())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Hidden layers
model.add(tf.keras.layers.Dense(200, activation='relu', name='Layer_1'))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(100, activation='relu', name='Layer_2'))
model.add(tf.keras.layers.BatchNormalization())

#Dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.add(tf.keras.layers.Dense(10, activation='softmax', name='Output'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# Layer_1 (Dense)              (None, 200)               157000
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 200)               800
# _________________________________________________________________
# Layer_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 10)                1010
# =================================================================
# Total params: 182,446
# Trainable params: 180,278
# Non-trainable params: 2,168
# _________________________________________________________________

# %%
#Train the model
model.fit(trainX,trainY,
          validation_data=(testX,testY),
          epochs=40,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.5152 - acc: 0.8169 - val_loss: 0.3961 - val_acc: 0.8582
# Epoch 2/40
# 60000/60000 [==============================] - 12s 202us/sample - loss: 0.3945 - acc: 0.8554 - val_loss: 0.3733 - val_acc: 0.8650
# Epoch 3/40
# 60000/60000 [==============================] - 12s 200us/sample - loss: 0.3578 - acc: 0.8684 - val_loss: 0.3852 - val_acc: 0.8713
# Epoch 4/40
# 60000/60000 [==============================] - 13s 222us/sample - loss: 0.3358 - acc: 0.8769 - val_loss: 0.3964 - val_acc: 0.8689
# Epoch 5/40
# 60000/60000 [==============================] - 12s 201us/sample - loss: 0.3139 - acc: 0.8849 - val_loss: 0.3489 - val_acc: 0.8814
# Epoch 6/40
# 60000/60000 [==============================] - 12s 203us/sample - loss: 0.3010 - acc: 0.8892 - val_loss: 0.3426 - val_acc: 0.8812
# Epoch 7/40
# 60000/60000 [==============================] - 12s 203us/sample - loss: 0.2874 - acc: 0.8941 - val_loss: 0.3845 - val_acc: 0.8788
# Epoch 8/40
# 60000/60000 [==============================] - 12s 204us/sample - loss: 0.2757 - acc: 0.8981 - val_loss: 0.3307 - val_acc: 0.8877
# Epoch 9/40
# 60000/60000 [==============================] - 12s 207us/sample - loss: 0.2672 - acc: 0.9006 - val_loss: 0.3915 - val_acc: 0.8863
# Epoch 10/40
# 60000/60000 [==============================] - 14s 226us/sample - loss: 0.2570 - acc: 0.9044 - val_loss: 0.3454 - val_acc: 0.8848
# Epoch 11/40
# 60000/60000 [==============================] - 13s 209us/sample - loss: 0.2478 - acc: 0.9074 - val_loss: 0.3380 - val_acc: 0.8904
# Epoch 12/40
# 60000/60000 [==============================] - 12s 208us/sample - loss: 0.2438 - acc: 0.9092 - val_loss: 0.3371 - val_acc: 0.8839
# Epoch 13/40
# 60000/60000 [==============================] - 12s 207us/sample - loss: 0.2321 - acc: 0.9136 - val_loss: 0.3521 - val_acc: 0.8897
# Epoch 14/40
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.2270 - acc: 0.9154 - val_loss: 0.3538 - val_acc: 0.8882
# Epoch 15/40
# 60000/60000 [==============================] - 13s 215us/sample - loss: 0.2235 - acc: 0.9164 - val_loss: 0.3711 - val_acc: 0.8906
# Epoch 16/40
# 60000/60000 [==============================] - 12s 206us/sample - loss: 0.2145 - acc: 0.9201 - val_loss: 0.3583 - val_acc: 0.8908
# Epoch 17/40
# 60000/60000 [==============================] - 12s 197us/sample - loss: 0.2096 - acc: 0.9212 - val_loss: 0.3527 - val_acc: 0.8912
# Epoch 18/40
# 60000/60000 [==============================] - 12s 194us/sample - loss: 0.2052 - acc: 0.9230 - val_loss: 0.4198 - val_acc: 0.8918
# Epoch 19/40
# 60000/60000 [==============================] - 12s 208us/sample - loss: 0.2005 - acc: 0.9243 - val_loss: 0.3231 - val_acc: 0.8959
# Epoch 20/40
# 60000/60000 [==============================] - 12s 207us/sample - loss: 0.1968 - acc: 0.9255 - val_loss: 0.4213 - val_acc: 0.8900
# Epoch 21/40
# 60000/60000 [==============================] - 12s 205us/sample - loss: 0.1902 - acc: 0.9290 - val_loss: 0.3659 - val_acc: 0.8888
# Epoch 22/40
# 60000/60000 [==============================] - 12s 206us/sample - loss: 0.1892 - acc: 0.9273 - val_loss: 0.4001 - val_acc: 0.8896
# Epoch 23/40
# 60000/60000 [==============================] - 12s 205us/sample - loss: 0.1818 - acc: 0.9323 - val_loss: 0.3891 - val_acc: 0.8941
# Epoch 24/40
# 60000/60000 [==============================] - 13s 210us/sample - loss: 0.1827 - acc: 0.9322 - val_loss: 0.3921 - val_acc: 0.8880
# Epoch 25/40
# 60000/60000 [==============================] - 12s 208us/sample - loss: 0.1786 - acc: 0.9326 - val_loss: 0.3664 - val_acc: 0.8923
# Epoch 26/40
# 60000/60000 [==============================] - 12s 205us/sample - loss: 0.1752 - acc: 0.9347 - val_loss: 0.3824 - val_acc: 0.8919
# Epoch 27/40
# 60000/60000 [==============================] - 12s 204us/sample - loss: 0.1712 - acc: 0.9354 - val_loss: 0.4210 - val_acc: 0.8917
# Epoch 28/40
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.1655 - acc: 0.9377 - val_loss: 0.3826 - val_acc: 0.8923
# Epoch 29/40
# 60000/60000 [==============================] - 12s 201us/sample - loss: 0.1645 - acc: 0.9396 - val_loss: 0.3580 - val_acc: 0.8930
# Epoch 30/40
# 60000/60000 [==============================] - 12s 207us/sample - loss: 0.1647 - acc: 0.9380 - val_loss: 0.3812 - val_acc: 0.8926
# Epoch 31/40
# 60000/60000 [==============================] - 12s 199us/sample - loss: 0.1580 - acc: 0.9400 - val_loss: 0.4311 - val_acc: 0.8928
# Epoch 32/40
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.1570 - acc: 0.9403 - val_loss: 0.3897 - val_acc: 0.8934
# Epoch 33/40
# 60000/60000 [==============================] - 12s 198us/sample - loss: 0.1538 - acc: 0.9420 - val_loss: 0.4218 - val_acc: 0.8884
# Epoch 34/40
# 60000/60000 [==============================] - 12s 202us/sample - loss: 0.1546 - acc: 0.9422 - val_loss: 0.4251 - val_acc: 0.8940
# Epoch 35/40
# 60000/60000 [==============================] - 13s 220us/sample - loss: 0.1490 - acc: 0.9436 - val_loss: 0.3768 - val_acc: 0.8941
# Epoch 36/40
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.1475 - acc: 0.9446 - val_loss: 0.4311 - val_acc: 0.8941
# Epoch 37/40
# 60000/60000 [==============================] - 12s 205us/sample - loss: 0.1459 - acc: 0.9457 - val_loss: 0.4432 - val_acc: 0.8908
# Epoch 38/40
# 60000/60000 [==============================] - 12s 207us/sample - loss: 0.1455 - acc: 0.9450 - val_loss: 0.4115 - val_acc: 0.8919
# Epoch 39/40
# 60000/60000 [==============================] - 12s 204us/sample - loss: 0.1398 - acc: 0.9477 - val_loss: 0.4479 - val_acc: 0.8919
# Epoch 40/40
# 60000/60000 [==============================] - 12s 202us/sample - loss: 0.1391 - acc: 0.9475 - val_loss: 0.5391 - val_acc: 0.8924
